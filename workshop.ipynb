# %% [markdown]
# <a href="https://colab.research.google.com/github/danielpcox/fastai-workshop/blob/master/workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fast.AI Quickstart
#
# * Based on [a notebook by Francisco Ingham and Jeremy Howard](https://github.com/fastai/course-v3/blob/master/nbs/dl1/lesson2-download.ipynb).
# * Mangled into a Colab workshop by Daniel Cox

# %% [markdown]
# Change runtime type to GPU from Colab menus:
#
# > Runtime -> Change runtime type -> Hardware accelerator -> GPU
#
# Colab already has fastai installed, but when you run inference locally you'll need to install it with
#
#
# ```
# pip3 install fastai
# ```

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# We start by making a dataset from Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).
#
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# Save each csv file as, for example, `urls_teddy.csv`. In this example, we're assuming the CSV files have this naming pattern. We will upload the files to Colab shortly.

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
path = Path('data/bears')

# %%
folder = 'black'
file = 'urls_black.csv'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'teddy'
file = 'urls_teddy.csv'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'grizzly'
file = 'urls_grizzly.csv'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Then actually upload those CSV files. In Colab, you run the following cell, and select those three files. Then we'll move them into the correct place, and check that they're there.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b2e4f3fe-c67f-49ab-be4a-45fcfd529ae8" name="files[]" multiple disabled />
#      <output id="result-b2e4f3fe-c67f-49ab-be4a-45fcfd529ae8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_black.csv to urls_black.csv
# Saving urls_grizzly.csv to urls_grizzly.csv
# Saving urls_teddy.csv to urls_teddy.csv
# ...

# %%
# !mv *.csv data/bears/

# %%
path.ls()
# Out:
# [PosixPath('data/bears/grizzly'),
#  PosixPath('data/bears/teddy'),
#  PosixPath('data/bears/urls_teddy.csv'),
#  PosixPath('data/bears/urls_black.csv'),
#  PosixPath('data/bears/black'),
#  PosixPath('data/bears/urls_grizzly.csv')]

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will only download the first 200 urls.

# %%
classes = ['teddy','grizzly','black']
for c in classes:
  file = 'urls_'+c+'.csv'
  folder = c
  dest = path/folder
  download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:11<00:00]
#     </div>
# ...

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# teddy
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='196' class='' max='196', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [196/196 00:06<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/bears/teddy/00000172.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddy/00000151.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddy/00000022.png'>
# ...

# %%
(path / 'teddy').ls()[0:10]
# Out:
# [PosixPath('data/bears/teddy/00000012.jpg'),
#  PosixPath('data/bears/teddy/00000078.jpeg'),
#  PosixPath('data/bears/teddy/00000062.jpg'),
#  PosixPath('data/bears/teddy/00000199.jpg'),
#  PosixPath('data/bears/teddy/00000156.jpg'),
#  PosixPath('data/bears/teddy/00000194.jpg'),
#  PosixPath('data/bears/teddy/00000161.JPG'),
#  PosixPath('data/bears/teddy/00000011.jpg'),
#  PosixPath('data/bears/teddy/00000037.jpg'),
#  PosixPath('data/bears/teddy/00000007.jpeg')]

# %% [markdown]
# ## View data
#
# Here we're creating a `DataBunch`, which is fastai's data loader. It's powerful, and does a lot for you. The `ImageDataBunch` has helper methods and settings particular to loading images.
#
# We're loading from our `data/bears` folder, setting aside a random 20% of the data as a validation set (don't train on it, but use it to see how we're doing), [applying transformations appropriate to the kinds of photos people take](https://docs.fast.ai/vision.transform.html) to augment our data, resizing the images to 224x224px, and using 4 concurrent processes to speed things up. We're also using imagenet normalizations because that's what the pretrained ResNet34 model expects. (More on that later.)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddy']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddy'], 3, 452, 113)

# %% [markdown]
# ## Train model
#
# Here we create a learner for images. CNNs are "convolutional neural networks", which preserve information related to pixel locality within the image.
#
# We're also not starting from scratch here: We're downloading a pre-trained model, ResNet34, and then tacking on a final fully-connected layer which we train to classify using our own class labels.

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:01, 65252960.29it/s]

# %% [markdown]
# By default, the neural net layers that we downloaded are "frozen", which means we don't train them. Let's start by training only the final layer we added, for four epochs, using the data we setup.

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:45 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.893088</td>
#       <td>0.147325</td>
#       <td>0.000000</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.496692</td>
#       <td>0.019655</td>
#       <td>0.000000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.334862</td>
#       <td>0.011849</td>
#       <td>0.000000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.251888</td>
#       <td>0.011975</td>
#       <td>0.000000</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The loss is going down, so we know things are improving. Crucially, the loss is also going down on the validation set.
# We sage our model after this first stage of training.

# %%
learn.save('stage-1')

# %% [markdown]
# Now to unfreeze all of those ResNet34 layers, allowing them to be trained as well.

# %%
learn.unfreeze()

# %% [markdown]
# Before we continue training, let's apply a trick. We're going to run a few epochs of training, each with a different learning rate, and then plot the loss against the learning rate. This allows us to pick a learning rate that will train our model as fast as possible, without making catastrophically large updates.

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# We want to set our learning rate for our own layers to slightly before the loss skyrockets. We also get to set the learning rate for the ResNet34 layers, which Jeremy Howard recommends setting to an order of magnitude lower.

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 00:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.118159</td>
#       <td>0.093895</td>
#       <td>0.070796</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.113520</td>
#       <td>0.159203</td>
#       <td>0.035398</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since this has made a significant improvement in the losses, we want to save this model.

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %% [markdown]
# The loss is a helpful _relative_ measure, but how well are we doing in an absolute sense?

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# A confusion matrix uses the validation set to tell you what got misclassified, and as what.

# %%
interp.plot_top_losses(9, figsize=(7,7))

# %% [markdown]
# We can also see which images had the worst loss, and what parts of the image the model focused on.

# %% [markdown]
# ## Cleaning Up (skip in Colab)
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .no_split()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
ImageCleaner(ds, idxs, path)

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, loosing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01<00:00]
#     </div>
# Computing similarities...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
# ...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# 'No images to show :)'

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %%
path.ls()
# Out:
# [PosixPath('data/bears/grizzly'),
#  PosixPath('data/bears/models'),
#  PosixPath('data/bears/teddy'),
#  PosixPath('data/bears/urls_teddy.csv'),
#  PosixPath('data/bears/urls_black.csv'),
#  PosixPath('data/bears/black'),
#  PosixPath('data/bears/urls_grizzly.csv'),
#  PosixPath('data/bears/export.pkl')]

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 500, 425)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Bad training data
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# ...

# %% [markdown]
# ### The Documentation
#
# * [The Fast.AI documentation](https://docs.fast.ai/) is really good.
# * We've been working with [the `vision` package](https://docs.fast.ai/vision.html), but it also has built-in support for [`text`](https://docs.fast.ai/text.html#text) and [`tabular`](https://docs.fast.ai/tabular.html#tabular) data.
# * If you have image data, the fastest way to get going is to follow the pattern above, putting your images in the right directories, though the fastai library has other options for loading data.
# * If you don't have image data, you may want to consider transforming it into image data and following this pattern. Otherwise, you can read the docs to see how to process text or tables.
#
#
# ### Questions?
